# %%
import numpy as np
from sklearn.feature_extraction import FeatureHasher
import pandas as pd
import os

# %% [markdown]
# # Prepare Training data

# %%
# local_raw_data = '../data/ordered_ex1_train.csv'
local_raw_data = 'ordered_ex1_train.csv'

# %%
raw_data_df = pd.read_csv(local_raw_data)

# %%
# target (percentage of having adverse events) = number_of_sae_subjects / enrollment
raw_data_df['target'] = raw_data_df['number_of_sae_subjects'] / raw_data_df['enrollment']

# %%
# drop number_of_sae_subjects and enrollment
raw_data_df.drop(raw_data_df.columns[[7,8]], axis=1, inplace=True)

# %%
# convert dataframe to ndarray
raw_data = raw_data_df.as_matrix()

# %%
# map has_us_facilities value ('t','f') -> (1, 0)
raw_data[raw_data[:,4] == 't',4]= 1
raw_data[raw_data[:,4] == 'f',4]= 0

# %% [markdown]
# ## Feature hashing

# %%
def merge_category(id_cat):
    output = []
    prev_id = None
    tmp = {}
    for nct_id, cat in id_cat:
        if prev_id is None or prev_id == nct_id:
            if prev_id is None:
                prev_id = nct_id
            tmp[cat] = 1
        else:
            output.append(tmp)
            # reset
            tmp = {}
            tmp[cat] = 1
            prev_id = nct_id
    output.append(tmp)
    print('output number of merged unique ids: {}'.format(len(output)))
    return output

# %% [markdown]
# ### Convert conditions, interventions and countries to hash feature

# %%
unique_ids = np.unique(raw_data[:,0])
number_of_uniqueID = unique_ids.shape[0]
print('number of unique nct_ids: {}'.format(number_of_uniqueID))
# Out:
# number of unique nct_ids: 16677

# %%
conditions = raw_data[:,[0,1]]
interventions = raw_data[:,[0,2]]
countries = raw_data[:,[0,5]]

# %% [markdown]
# > TODO: draw frequency distribution of the three features

# %%
interventions[:,1]
# Out:
# array(['ganciclovir', 'ganciclovir', 'ganciclovir', ..., 'oxycodone',
#        'fentanyl', 'adenosine'], dtype=object)

# %%
# preprocess the high dimentional features before feed into feature hasher
merged_conditions = merge_category(conditions)
merged_interventions = merge_category(interventions)
merged_countries = merge_category(countries)
# Out:
# output number of merged unique ids: 16677
# output number of merged unique ids: 16677
# output number of merged unique ids: 16677

# %%
number_of_conditions = np.unique(conditions[:,1]).shape[0]
print('number of unique conditions: {}'.format(number_of_conditions))

number_of_interventions = np.unique(interventions[:,1]).shape[0]
print('number of unique interventions: {}'.format(number_of_interventions))

number_of_countries = np.unique(countries[:,1]).shape[0]
print('number of unique countries: {}'.format(number_of_countries))
# Out:
# number of unique conditions: 1909
# number of unique interventions: 1846
# number of unique countries: 142

# %%
# feature hasher
conditions_hasher = FeatureHasher(n_features=int(number_of_conditions * 0.2),
                                                             non_negative=True,input_type='dict')
interventions_hasher = FeatureHasher(n_features=int(number_of_interventions * 0.2),
                                                             non_negative=True,input_type='dict')
countries_hasher = FeatureHasher(n_features=int(number_of_countries),
                                                             non_negative=True,input_type='dict')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)

# %%
# apply feature hashing
conditions_feature = conditions_hasher.fit_transform(merged_conditions).toarray()
print('conditions_feature shape: {}'.format(conditions_feature.shape))

interventions_feature = interventions_hasher.fit_transform(merged_interventions).toarray()
print('interventions_feature shape: {}'.format(interventions_feature.shape))

countries_feature = countries_hasher.fit_transform(merged_countries).toarray()
print('countries_feature shape: {}'.format(countries_feature.shape))
# Out:
# conditions_feature shape: (16677, 381)
# interventions_feature shape: (16677, 369)
# countries_feature shape: (16677, 142)

# %% [markdown]
# ### Appending the hashed feature to training data

# %%
raw_data[0]
# Out:
# array(['NCT00000143', 'hiv infections', 'ganciclovir', 19, 1,
#        'United States', 1, 0.0], dtype=object)

# %%
# drop the old conditions, interventions and countries
prev_id = None
new_data = []
tmp = []
idx = 0
for data in raw_data:
    cur_id = data[0]
    if prev_id is None or cur_id != prev_id:
        tmp.append(cur_id)
        tmp.append(data[3])
        tmp.append(data[4])
        tmp.append(data[6])
        
        tmp += conditions_feature[idx].tolist()
        tmp += interventions_feature[idx].tolist()
        tmp += countries_feature[idx].tolist()
        
        tmp.append(data[7])
        
        new_data.append(tmp)
        
        # update
        prev_id = cur_id
        tmp = []
        idx += 1

# new data shape: nct_id, number_of_facilities, has_us_facility, 
# number_of_sponsors, conditions_features, interventions_features, contries_features, percentage_of_adverse_event (target)
new_data = np.array(new_data)
print('reconstructed training data shape: {}'.format(new_data.shape))
# Out:
# reconstructed training data shape: (16677, 897)

# %% [markdown]
# > note: remove the first nct_id column before send to model

# %%
# randomly shuffle the data before categorization
np.random.shuffle(new_data)

# %%
train_size = int(new_data.shape[0] * 0.7)
train_features  = new_data[:train_size, :-1]
train_features
# Out:
# array([['NCT01349959', '7', '1', ..., '0.0', '0.0', '0.0'],
#        ['NCT00703937', '1', '1', ..., '0.0', '0.0', '0.0'],
#        ['NCT01575899', '1', '0', ..., '0.0', '0.0', '0.0'],
#        ...,
#        ['NCT00805142', '22', '0', ..., '0.0', '0.0', '0.0'],
#        ['NCT01733316', '13', '1', ..., '0.0', '1.0', '0.0'],
#        ['NCT01027351', '1', '0', ..., '0.0', '0.0', '0.0']], dtype='<U22')

# %%
train_size = int(new_data.shape[0] * 0.7)
train_features  = new_data[:train_size, :-1]
train_labels = new_data[:train_size, -1]
print('train_features shape: {}'.format(train_features.shape))

validation_size = int(new_data.shape[0] * 0.2)
validation_features = new_data[train_size:train_size + validation_size, :-1]
validation_labels = new_data[train_size:train_size + validation_size, -1]
print('validation_features shape: {}'.format(validation_features.shape))

test_features = new_data[train_size + validation_size:, :-1]
test_labels = new_data[train_size + validation_size:, -1]
print('test_features shape: {}'.format(test_features.shape))
# Out:
# train_features shape: (11673, 896)
# validation_features shape: (3335, 896)
# test_features shape: (1669, 896)

# %%
feature_dim = train_features[:,1:].shape[1]
print('feature dimention: {}'.format(feature_dim))
# Out:
# feature dimention: 895

# %% [markdown]
# ### Data conversion
#
# convert the numpy array into recordIO-protobuf or CSV format that can be used by sagemaker linear_learner
# model specs: https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html
#
# Since algorithms have particular input and output requirements, converting the dataset is also part of the process that a data scientist goes through prior to initiating training. In this particular case, the Amazon SageMaker implementation of Linear Learner takes recordIO-wrapped protobuf, where the data we have today is a pickle-ized numpy array on disk.
#
# Most of the conversion effort is handled by the Amazon SageMaker Python SDK, imported as `sagemaker` below.

# %%
import boto3
import re
import sagemaker.amazon.common as smac
import io
from sagemaker import get_execution_role
import sagemaker

bucket = 'sagemaker-tiber-solution'
prefix = 'logistic-regression/yangz5'
s3_train_key = '{}/train/recordio-pb-data'.format(prefix)
s3_train_path = os.path.join('s3://', bucket, s3_train_key)

# Define IAM role
role = get_execution_role()

# %%
# traing data should be excluding the first nct_id column 
vectors = np.array([t.tolist() for t in train_features[:,1:]]).astype('float32')
labels = np.array([t.tolist() for t in train_labels]).astype('float32')
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)
boto3.resource('s3').Bucket(bucket).Object(s3_train_key).upload_fileobj(buf)

# %% [markdown]
# Wrapping the model training setup in a convenience function that takes in the S3 location of the training data, the model hyperparameters that define our training job, and the S3 output path for model artifacts.  Inside the function, we'll hardcode the algorithm container, the number and type of EC2 instances to train on, and the input and output data formats.

# %%
def predictor_from_hyperparams(s3_train_data, hyperparams, output_path):
    """
    Create an Estimator from the given hyperparams, fit to training data, and return a deployed predictor
    """
    # specify algorithm containers and instantiate an Estimator with given hyperparams
    containers = {
        'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/linear-learner:latest',
        'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:latest',
        'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/linear-learner:latest',
        'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/linear-learner:latest'}
    linear = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
        role,
        train_instance_count=1,
        train_instance_type='ml.m4.xlarge',
        output_path=output_path,
        sagemaker_session=sagemaker.Session())
    linear.set_hyperparameters(**hyperparams)
    # train model
    linear.fit({'train': s3_train_data})
#     # deploy a predictor
#     linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
#     linear_predictor.content_type = 'text/csv'
#     linear_predictor.serializer = csv_serializer
#     linear_predictor.deserializer = json_deserializer
#     return linear_predictor

    # return the trained model, for now
    return linear

# %%
# Training a binary classifier with default settings: logistic regression
defaults_hyperparams = {
    'feature_dim': feature_dim,
    'predictor_type': 'regressor',
    'epochs': 10
}
defaults_output_path = 's3://{}/{}/defaults/output'.format(bucket, prefix)
defaults_predictor = predictor_from_hyperparams(s3_train_path, defaults_hyperparams, defaults_output_path)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2018-04-11-16-39-20-286
# ..................................................................
# Docker entrypoint called with argument(s): train
# [04/11/2018 16:44:44 INFO 139860162471744] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'10', u'init_bias': u'0.0', u'lr_scheduler_factor': u'0.99', u'num_calibration_samples': u'10000000', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'10', u'lr_scheduler_step': u'100', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'0.00001', u'target_recall': u'0.8', u'num_models': u'32', u'early_stopping_patience': u'3', u'momentum': u'0.0', u'unbias_label': u'auto', u'wd': u'0.0', u'optimizer': u'adam', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'force_dense': u'true', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'beta_1': u'0.9', u'loss': u'auto', u'beta_2': u'0.999', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'_data_format': u'record', u'positive_example_weight_mult': u'1.0', u'l1': u'0.0', u'margin': u'1.0'}
# [04/11/2018 16:44:44 INFO 139860162471744] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'10', u'feature_dim': u'895', u'predictor_type': u'regressor'}
# [04/11/2018 16:44:44 INFO 139860162471744] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'10', u'feature_dim': u'895', u'init_bias': u'0.0', u'lr_scheduler_factor': u'0.99', u'num_calibration_samples': u'10000000', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'10', u'lr_scheduler_step': u'100', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'0.00001', u'target_recall': u'0.8', u'num_models': u'32', u'early_stopping_patience': u'3', u'momentum': u'0.0', u'unbias_label': u'auto', u'wd': u'0.0', u'optimizer': u'adam', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'force_dense': u'true', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'beta_1': u'0.9', u'loss': u'auto', u'beta_2': u'0.999', u'predictor_type': u'regressor', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'_data_format': u'record', u'positive_example_weight_mult': u'1.0', u'l1': u'0.0', u'margin': u'1.0'}
# [04/11/2018 16:44:44 WARNING 139860162471744] Loggers have already been setup.
# [04/11/2018 16:44:44 INFO 139860162471744] Using default worker.
# [04/11/2018 16:44:44 INFO 139860162471744] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [04/11/2018 16:44:44 INFO 139860162471744] Create Store: local
# [04/11/2018 16:44:45 WARNING 139860162471744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/11/2018 16:44:45 INFO 139860162471744] nvidia-smi took: 0.0252261161804 secs to identify 0 gpus
# [04/11/2018 16:44:45 INFO 139860162471744] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1523465085.15093, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1523465085.150891}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.521425742409446, "sum": 1.521425742409446, "min": 1.521425742409446}}, "EndTime": 1523465085.578601, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.578455}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.541993624600497, "sum": 1.541993624600497, "min": 1.541993624600497}}, "EndTime": 1523465085.578717, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.578698}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.5716380615234375, "sum": 1.5716380615234375, "min": 1.5716380615234375}}, "EndTime": 1523465085.578845, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.578777}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.6870089888139204, "sum": 1.6870089888139204, "min": 1.6870089888139204}}, "EndTime": 1523465085.57891, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.578895}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 9.469574174360796, "sum": 9.469574174360796, "min": 9.469574174360796}}, "EndTime": 1523465085.578987, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.578947}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 9.02822509765625, "sum": 9.02822509765625, "min": 9.02822509765625}}, "EndTime": 1523465085.579042, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579029}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 8.612540571732955, "sum": 8.612540571732955, "min": 8.612540571732955}}, "EndTime": 1523465085.579088, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579077}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 10.07182666015625, "sum": 10.07182666015625, "min": 10.07182666015625}}, "EndTime": 1523465085.579159, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579133}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.6468653231534092, "sum": 1.6468653231534092, "min": 1.6468653231534092}}, "EndTime": 1523465085.579211, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579199}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.5649906283291903, "sum": 1.5649906283291903, "min": 1.5649906283291903}}, "EndTime": 1523465085.579257, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579246}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.6078512018377131, "sum": 1.6078512018377131, "min": 1.6078512018377131}}, "EndTime": 1523465085.579303, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579291}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 1.6151873779296875, "sum": 1.6151873779296875, "min": 1.6151873779296875}}, "EndTime": 1523465085.579348, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579336}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 8.826937433416193, "sum": 8.826937433416193, "min": 8.826937433416193}}, "EndTime": 1523465085.579393, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579381}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 9.10831620649858, "sum": 9.10831620649858, "min": 9.10831620649858}}, "EndTime": 1523465085.579438, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1523465085.579427}
#
# #metrics {"Metrics": {"training_mse": {"count": 1, "max": 9
"Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1523465088.686506}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Number of Batches Since Last Reset": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Number of Records Since Last Reset": {"count": 1, "max": 11673, "sum": 11673.0, "min": 11673}, "Total Batches Seen": {"count": 1, "max": 132, "sum": 132.0, "min": 132}, "Total Records Seen": {"count": 1, "max": 128730, "sum": 128730.0, "min": 128730}, "Max Records Seen Between Resets": {"count": 1, "max": 11673, "sum": 11673.0, "min": 11673}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1523465088.687081, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1523465088.687045}
#
# [04/11/2018 16:44:48 WARNING 139860162471744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/11/2018 16:44:48 WARNING 139860162471744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/11/2018 16:44:48 INFO 139860162471744] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [04/11/2018 16:44:48 INFO 139860162471744] Saved checkpoint to "/tmp/tmpNLbVWr/mx-mod-0000.params"
# [04/11/2018 16:44:48 INFO 139860162471744] Test data was not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4255.166053771973, "sum": 4255.166053771973, "min": 4255.166053771973}, "finalize.time": {"count": 1, "max": 22.60899543762207, "sum": 22.60899543762207, "min": 22.60899543762207}, "initialize.time": {"count": 1, "max": 586.9519710540771, "sum": 586.9519710540771, "min": 586.9519710540771}, "check_early_stopping.time": {"count": 10, "max": 1.7349720001220703, "sum": 9.31096076965332, "min": 0.07510185241699219}, "setuptime": {"count": 1, "max": 28.873920440673828, "sum": 28.873920440673828, "min": 28.873920440673828}, "update.time": {"count": 10, "max": 431.1859607696533, "sum": 3525.9528160095215, "min": 324.268102645874}, "epochs": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1523465088.716948, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1523465084.531738}
# ===== Job Complete =====
# Billable seconds: 172

# %%
logistic_predictor = defaults_predictor.deploy(initial_instance_count=1, instance_type='ml.t2.medium')

# %%
from sagemaker.predictor import csv_serializer, json_deserializer
logistic_predictor.content_type = 'text/csv'
logistic_predictor.serializer = csv_serializer
logistic_predictor.deserializer = json_deserializer

# %%
result = []

for idx, train_line in enumerate(test_features):
    prediction = logistic_predictor.predict(train_line[1:].reshape(1, -1))
    result.append((train_line[0], prediction['predictions'][0]['score'], float(test_labels[idx])))
#     print('idx: {}, nct_id: {}, prediction: {}, label: {}'.format(idx, train_line[0], prediction['predictions'][0]['score'], train_labels[idx]))
# Out:
# {'predictions': [{'score': 1.4546172618865967}]}
# idx: 0, nct_id: NCT01349959, prediction: 1.4546172618865967, label: 0.425
# {'predictions': [{'score': 0.5182403326034546}]}
# idx: 1, nct_id: NCT00703937, prediction: 0.5182403326034546, label: 0.08192090395480225
# {'predictions': [{'score': 0.7158364057540894}]}
# idx: 2, nct_id: NCT01575899, prediction: 0.7158364057540894, label: 0.009615384615384616
# {'predictions': [{'score': 0.03394302725791931}]}
# idx: 3, nct_id: NCT00621517, prediction: 0.03394302725791931, label: 0.03333333333333333
# {'predictions': [{'score': 0.6007420420646667}]}
# idx: 4, nct_id: NCT01100853, prediction: 0.6007420420646667, label: 0.32
# {'predictions': [{'score': 0.29297369718551636}]}
# idx: 5, nct_id: NCT01444651, prediction: 0.29297369718551636, label: 0.0
# {'predictions': [{'score': 0.23890921473503113}]}
# idx: 6, nct_id: NCT02114931, prediction: 0.23890921473503113, label: 0.22269807280513917
# {'predictions': [{'score': -0.05315151810646057}]}
# idx: 7, nct_id: NCT00885079, prediction: -0.05315151810646057, label: 0.0
# {'predictions': [{'score': 0.5971255302429199}]}
# idx: 8, nct_id: NCT01427751, prediction: 0.5971255302429199, label: 0.21498371335504887
# {'predictions': [{'score': 0.2092391550540924}]}
# idx: 9, nct_id: NCT01456299, prediction: 0.2092391550540924, label: 0.0
# {'predictions': [{'score': 1.1214134693145752}]}
# idx: 10, nct_id: NCT01193244, prediction: 1.1214134693145752, label: 1.3192307692307692
# {'predictions': [{'score': 0.13179044425487518}]}
# idx: 11, nct_id: NCT00455650, prediction: 0.13179044425487518, label: 0.0
# {'predictions': [{'score': -0.24717146158218384}]}
# idx: 12, nct_id: NCT00618332, prediction: -0.24717146158218384, label: 0.0
# {'predictions': [{'score': 0.4059637188911438}]}
# idx: 13, nct_id: NCT00498615, prediction: 0.4059637188911438, label: 0.0
# {'predictions': [{'score': 0.15157610177993774}]}
# idx: 14, nct_id: NCT01986231, prediction: 0.15157610177993774, label: 0.0
# {'predictions': [{'score': 0.3674517571926117}]}
# idx: 15, nct_id: NCT01547598, prediction: 0.3674517571926117, label: 0.022222222222222223
# {'predictions': [{'score': 0.03332427144050598}]}
# idx: 16, nct_id: NCT00225017, prediction: 0.03332427144050598, label: 0.0
# {'predictions': [{'score': 0.8173432946205139}]}
# idx: 17, nct_id: NCT00789828, prediction: 0.8173432946205139, label: 1.4786324786324787
# {'predictions': [{'score': 0.03054770827293396}]}
# idx: 18, nct_id: NCT00031551, prediction: 0.03054770827293396, label: 0.0
# {'predictions': [{'score': 0.8660740852355957}]}
# idx: 19, nct_id: NCT01379521, prediction: 0.8660740852355957, label: 0.6615384615384615
# {'predictions': [{'score': 0.07202991843223572}]}
# idx: 20, nct_id: NCT00590863, prediction: 0.07202991843223572, label: 0.13984962406015036
# {'predictions': [{'score': -0.18983817100524902}]}
# idx: 21, nct_id: NCT00621777, prediction: -0.18983817100524902, label: 0.11336032388663968
# {'predictions': [{'score': -0.07996755838394165}]}
# idx: 22, nct_id: NCT01948908, prediction: -0.07996755838394165, label: 0.0
# {'predictions': [{'score': 0.8011093735694885}]}
# idx: 23, nct_id: NCT00232479, prediction: 0.8011093735694885, label: 0.041666666666666664
# {'predictions': [{'score': 0.08776943385601044}]}
# idx: 24, nct_id: NCT01911429, prediction: 0.08776943385601044, label: 0.09174311926605505
# {'predictions': [{'score': -0.33234018087387085}]}
# idx: 25, nct_id: NCT00661479, prediction: -0.33234018087387085, label: 0.19047619047619047
# {'predictions': [{'score': 0.29830390214920044}]}
# idx: 26, nct_id: NCT00585104, prediction: 0.29830390214920044, label: 0.0
# {'predictions': [{'score': 0.6262013912200928}]}
# idx: 27, nct_id: NCT02628106, prediction: 0.6262013912200928, label: 0.0
# {'predictions': [{'score': 0.0272674560546875}]}
# idx: 28, nct_id: NCT01138098, prediction: 0.0272674560546875, label: 0.010810810810810811
# {'predictions': [{'score': 0.08521860837936401}]}
# idx: 29, nct_id: NCT00553280, prediction: 0.08521860837936401, label: 0.37398373983739835
# {'predictions': [{'score': 0.7616437673568726}]}
# idx: 30, nct_id: NCT00159822, prediction: 0.7616437673568726, label: 1.1875
# {'predictions': [{'score': 0.19471687078475952}]}
# idx: 31, nct_id: NCT01227824, prediction: 0.19471687078475952, label: 0.29830917874396135
# {'predictions': [{'score': 0.5460855960845947}]}
# idx: 32, nct_id: NCT00633893, prediction: 0.5460855960845947, label: 0.32239026189597936
# {'predictions': [{'score': 0.43135765194892883}]}
# idx: 33, nct_id: NCT01095094, prediction: 0.43135765194892883, label: 0.7894736842105263
# {'predictions': [{'score': 0.4313313663005829}]}
# idx: 34, nct_id: NCT02132468, prediction: 0.4313313663005829, label: 0.3333333333333333
# {'predictions': [{'score': 0.5938589572906494}]}
# idx: 35, nct_id: NCT00352846, prediction: 0.5938589572906494, label: 0.0
# {'predictions': [{'score': 0.9137782454490662}]}
# idx: 36, nct_id: NCT00335959, prediction: 0.9137782454490662, label: 0.2857142857142857
# {'predictions': [{'score': -0.11442747712135315}]}
# idx: 37, nct_id: NCT01652495, prediction: -0.11442747712135315, label: 0.0
# {'predictions': [{'score': 0.7348328828811646}]}
# idx: 38, nct_id: NCT00660543, prediction: 0.7348328828811646, label: 0.0
# {'predictions': [{'score': 1.439013957977295}]}
# idx: 39, nct_id: NCT00603447, prediction: 1.439013957977295, label: 1.369047619047619
# {'predictions': [{'score': -0.22877001762390137}]}
# idx: 40, nct_id: NCT01511939, prediction: -0.22877001762390137, label: 0.09090909090909091
# {'predictions': [{'score': 0.8489950299263}]}
# idx: 41, nct_id: NCT00326885, prediction: 0.8489950299263, label: 2.625
# {'predictions': [{'score': 0.4052537679672241}]}
# idx: 42, nct_id: NCT00359632, prediction: 0.4052537679672241, label: 0.4411764705882353
# {'predictions': [{'score': 1.299447774887085}]}
# idx: 43, nct_id: NCT00996333, prediction: 1.299447774887085, label: 0.8478260869565217
# {'predictions': [{'score': 0.4242292642593384}]}
# idx: 44, nct_id: NCT00752986, prediction: 0.4242292642593384, label: 0.358974358974359
# {'predictions': [{'score': 0.3535633981227875}]}
# idx: 45, nct_id: NCT00344968, prediction: 0.3535633981227875, label: 2.7144351464435146
# {'predictions': [{'score': 1.0238759517669678}]}
# idx: 46, nct_id: NCT00954941, prediction: 1.0238759517669678, label: 0.12
# {'predictions': [{'score': -0.24806559085845947}]}
# idx: 47, nct_id: NCT01982695, prediction: -0.24806559085845947, label: 0.0
# {'predictions': [{'score': 0.2022509127855301}]}
# idx: 48, nct_id: NCT00557245, prediction: 0.2022509127855301, label: 0.16078184110970997
# {'predictions': [{'score': 0.8352094888687134}]}
# idx: 49, nct_id: NCT00290407, prediction: 0.8352094888687134, label: 0.0
# {'predictions': [{'score': 0.047539159655570984}]}
# idx: 50, nct_id: NCT01404208, prediction: 0.047539159655570984, label: 0.0
# {'predictions': [{'score': 0.8412876725196838}]}
# idx: 51, nct_id: NCT00479674, prediction: 0.8412876725196838, label: 1.5121951219512195
# {'predictions': [{'score': 0.2689322233200073}]}
# idx: 52, nct_id: NCT01333722, prediction: 0.2689322233200073, label: 0.0
# {'predictions': [{'score': 0.3864104747772217}]}
# idx: 53, nct_id: NCT00351819, prediction: 0.3864104747772217, label: 0.07142857142857142
# {'predictions': [{'score': 0.20885875821113586}]}
# idx: 54, nct_id: NCT00998335, prediction: 0.20885875821113586, label: 0.0
# {'predictions': [{'score': 0.25959205627441406}]}
# idx: 55, nct_id: NCT01940341, prediction: 0.25959205627441406, label: 0.1267605633802817
# {'predictions': [{'score': 0.11450058221817017}]}
# idx: 56, nct_id: NCT01181141, prediction: 0.11450058221817017, label: 0.13043478260869565
# {'predictions': [{'score': 0.30455365777015686}]}
# idx: 57, nct_id: NCT00329745, prediction: 0.30455365777015686, label: 0.005410383331414758
# {'predictions': [{'score': 1.3724658489227295}]}
# idx: 58, nct_id: NCT01660906, prediction: 1.3724658489227295, label: 0.6923076923076923
# {'predictions': [{'score': 0.2654626667499542}]}
# idx: 59, nct_id: NCT01519518, prediction: 0.2654626667499542, label: 0.0
# {'predictions': [{'score': 0.19169029593467712}]}
# idx: 60, nct_id: NCT00932022, prediction: 0.19169029593467712, label: 0.015748031496062992
# {'predictions': [{'score': 0.027668118476867676}]}
# idx: 61, nct_id: NCT00841672, prediction: 0.027668118476867676, label: 0.016494845360824743
# {'predictions': [{'score': 0.5030158162117004}]}
# idx: 62, nct_id: NCT01580618, prediction: 0.5030158162117004, label: 0.1
# {'predictions': [{'score': 0.4036823511123657}]}
# idx: 63, nct_id: NCT00107783, prediction: 0.4036823511123657, label: 0.35
# {'predictions': [{'score': 1.1495354175567627}]}
# idx: 64, nct_id: NCT00654186, prediction: 1.1495354175567627, label: 1.28125
# {'predictions': [{'score': 1.393427848815918}]}
# idx: 65, nct_id: NCT01969435, prediction: 1.393427848815918, label: 0.04
# {'predictions': [{'score': 0.03668370842933655}]}
# idx: 66, nct_id: NCT00985010, prediction: 0.03668370842933655, label: 0.0
# {'predictions': [{'score': 1.4654052257537842}]}
# idx: 67, nct_id: NCT01317615, prediction: 1.4654052257537842, label: 1.9387755102040816
# {'predictions': [{'score': -0.047054439783096313}]}
# idx: 68, nct_id: NCT00427700, prediction: -0.047054439783096313, label: 0.0
# {'predictions': [{'score': -0.0583270788192749}]}
# idx: 69, nct_id: NCT01017263, prediction: -0.0583270788192749, label: 0.0
# {'predictions': [{'score': -0.10395672917366028}]}
# idx: 70, nct_id: NCT00468481, prediction: -0.10395672917366028, label: 0.01818181818181818
# {'predictions': [{'score': 0.47391563653945923}]}
# idx: 71, nct_id: NCT00986154, prediction: 0.47391563653945923, label: 0.5062711046792089
# {'predictions': [{'score': 0.2617266774177551}]}
# idx: 72, nct_id: NCT00632970, prediction: 0.2617266774177551, label: 0.0
# {'predictions': [{'score': 0.3707788586616516}]}
# idx: 73, nct_id: NCT00141726, prediction: 0.3707788586616516, label: 0.29411764705882354
# {'predictions': [{'score': 0.9418501257896423}]}
# idx: 74, nct_id: NCT00344773, prediction: 0.9418501257896423, label: 0.21739130434782608
# {'predictions': [{'score': 0.18095743656158447}]}
# idx: 75, nct_id: NCT00849810, prediction: 0.18095743656158447, label: 0.0
# {'predictions': [{'score': 0.48093461990356445}]}
# idx: 76, nct_id: NCT01307462, prediction: 0.48093461990356445, label: 1.3611111111111112
# {'predictions': [{'score': 0.28142279386520386}]}
# idx: 77, nct_id: NCT01008605, prediction: 0.28142279386520386, label: 0.0
# {'predictions': [{'score': -0.1828984022140503}]}
# idx: 78, nct_id: NCT01688037, prediction: -0.1828984022140503, label: 0.11926605504587157
# {'predictions': [{'score': 0.21984103322029114}]}
# idx: 79, nct_id: NCT01606254, prediction: 0.21984103322029114, label: 0.25
# {'predictions': [{'score': 0.2993199825286865}]}
# idx: 80, nct_id: NCT01986361, prediction: 0.2993199825286865, label: 0.0
# {'predictions': [{'score': 0.4513372480869293}]}
# idx: 81, nct_id: NCT00887289, prediction: 0.4513372480869293, label: 0.007978723404255319
# {'predictions': [{'score': 0.33048900961875916}]}
# idx: 82, nct_id: NCT01204658, prediction: 0.33048900961875916, label: 0.24131944444444445
# {'predictions': [{'score': -0.05343484878540039}]}
# idx: 83, nct_id: NCT02648022, prediction: -0.05343484878540039, label: 0.42168674698795183
# {'predictions': [{'score': 1.268017053604126}]}
# idx: 84, nct_id: NCT00044512, prediction: 1.268017053604126, label: 1.9416058394160585
# {'predictions': [{'score': 0.06940877437591553}]}
# idx: 85, nct_id: NCT01156532, prediction: 0.06940877437591553, label: 0.06666666666666667
# {'predictions': [{'score': 0.6896617412567139}]}
# idx: 86, nct_id: NCT02203578, prediction: 0.6896617412567139, label: 2.0
# {'predictions': [{'score': 0.4079764485359192}]}
# idx: 87, nct_id: NCT00638365, prediction: 0.4079764485359192, label: 0.14814814814814814
# {'predictions': [{'score': 0.6858669519424438}]}
# idx: 88, nct_id: NCT00682786, prediction: 0.6858669519424438, label: 0.4148148148148148
# {'predictions': [{'score': 0.8118628859519958}]}
# idx: 89, nct_id: NCT01949870, prediction: 0.8118628859519958, label: 0.3333333333333333
# {'predictions': [{'score': 0.012407004833221436}]}
# idx: 90, nct_id: NCT00972283, prediction: 0.012407004833221436, label: 0.4393638170974155
# {'predictions': [{'score': 0.4394530653953552}]}
# idx: 91, nct_id: NCT01644474, prediction: 0.4394530653953552, label: 0.038834951456310676
# {'predictions': [{'score': 1.1199021339416504}]}
# idx: 92, nct_id: NCT00475657, prediction: 1.1199021339416504, label: 1.2
# {'predictions': [{'score': 0.11809438467025757}]}
# idx: 93, nct_id: NCT00242580, prediction: 0.11809438467025757, label: 0.7387387387387387
# {'predictions': [{'score': 1.4885585308074951}]}
# idx: 94, nct_id: NCT01191749, prediction: 1.4885585308074951, label: 0.7142857142857143
# {'predictions': [{'score': 0.3821718692779541}]}
# idx: 95, nct_id: NCT01976650, prediction: 0.3821718692779541, label: 0.011049723756906077
# {'predictions': [{'score': 0.49788761138916016}]}
# idx: 96, nct_id: NCT01458275, prediction: 0.49788761138916016, label: 0.0023612750885478157
# {'predictions': [{'score': 0.41052278876304626}]}
# idx: 97, nct_id: NCT00557466, prediction: 0.41052278876304626, label: 0.022887323943661973
# {'predictions': [{'score': 0.9256461262702942}]}
# idx: 98, nct_id: NCT00820872, prediction: 0.9256461262702942, label: 1.1333333333333333
# {'predictions': [{'score': 0.2723483443260193}]}
# idx: 99, nct_id: NCT00608842, prediction: 0.2723483443260193, label: 0.08064516129032258
# {'predictions': [{'score': 0.11737136542797089}]}
# idx: 100, nct_id: NCT01189487, prediction: 0.11737136542797089, label: 0.0425531914893617
# {'predictions': [{'score': 0.33663567900657654}]}
# idx: 101, nct_id: NCT00363142, prediction: 0.33663567900657654, label: 0.08056872037914692
# {'predictions': [{'score': 0.5304433107376099}]}
# idx: 102, nct_id: NCT00088985, prediction: 0.5304433107376099, label: 0.21428571428571427
# {'predictions': [{'score': 0.013278007507324219}]}
# idx: 103, nct_id: NCT01582490, prediction: 0.013278007507324219, label: 0.0
# {'predictions': [{'score': 0.8075703382492065}]}
# idx: 104, nct_id: NCT00314106, prediction: 0.8075703382492065, label: 1.5384615384615385
# {'predictions': [{'score': 0.9964364171028137}]}
# idx: 105, nct_id: NCT00815919, prediction: 0.9964364171028137, label: 0.18181818181818182
# {'predictions': [{'score': 0.021817192435264587}]}
# idx: 106, nct_id: NCT00699192, prediction: 0.021817192435264587, label: 0.017616580310880828
# {'predictions': [{'score': -0.06369578838348389}]}
# idx: 107, nct_id: NCT00468299, prediction: -0.06369578838348389, label: 0.0
# {'predictions': [{'score': 0.3835368752479553}]}
# idx: 108, nct_id: NCT01648140, prediction: 0.3835368752479553, label: 0.06293706293706294
# {'predictions': [{'score': 0.381325900554657}]}
# idx: 109, nct_id: NCT01485796, prediction: 0.381325900554657, label: 0.037037037037037035
# {'predictions': [{'score': 0.3937026858329773}]}
# idx: 110, nct_id: NCT01571557, prediction: 0.3937026858329773, label: 0.0034904013961605585
# {'predictions': [{'score': 0.35040518641471863}]}
# idx: 111, nct_id: NCT01860976, prediction: 0.35040518641471863, label: 0.06952965235173825
# {'predictions': [{'score': 0.753361165523529}]}
# idx: 112, nct_id: NCT01189435, prediction: 0.753361165523529, label: 0.0
# {'predictions': [{'score': -0.29408586025238037}]}
# idx: 113, nct_id: NCT00693017, prediction: -0.29408586025238037, label: 0.2
# {'predictions': [{'score': 1.4565727710723877}]}
# idx: 114, nct_id: NCT00588900, prediction: 1.4565727710723877, label: 4.0
# {'predictions': [{'score': 0.12926363945007324}]}
# idx: 115, nct_id: NCT01365650, prediction: 0.12926363945007324, label: 0.0
# {'predictions': [{'score': 0.7336673736572266}]}
# idx: 116, nct_id: NCT02834624, prediction: 0.7336673736572266, label: 0.0
# {'predictions': [{'score': 0.110692098736763}]}
# idx: 117, nct_id: NCT00934050, prediction: 0.110692098736763, label: 0.3786407766990291
# {'predictions': [{'score': 0.5624797940254211}]}
# idx: 118, nct_id: NCT02057250, prediction: 0.5624797940254211, label: 0.2626728110599078
# {'predictions': [{'score': 0.2113543450832367}]}
# idx: 119, nct_id: NCT01173874, prediction: 0.2113543450832367, label: 0.2
# {'predictions': [{'score': 0.5653671026229858}]}
# idx: 120, nct_id: NCT00303329, prediction: 0.5653671026229858, label: 1.8423913043478262
# {'predictions': [{'score': 0.5252392292022705}]}
# idx: 121, nct_id: NCT01953328, prediction: 0.5252392292022705, label: 0.029339853300733496
# {'predictions': [{'score': 0.06878811120986938}]}
# idx: 122, nct_id: NCT01043185, prediction: 0.06878811120986938, label: 0.14814814814814814
# {'predictions': [{'score': 0.36959972977638245}]}
# idx: 123, nct_id: NCT00377572, prediction: 0.36959972977638245, label: 0.3221957040572792
# {'predictions': [{'score': 0.452970027923584}]}
# idx: 124, nct_id: NCT00116805, prediction: 0.452970027923584, label: 0.5601503759398496
# {'predictions': [{'score': 0.05824156105518341}]}
# idx: 125, nct_id: NCT01852175, prediction: 0.05824156105518341, label: 0.0
# {'predictions': [{'score': 0.1941075325012207}]}
# idx: 126, nct_id: NCT00391027, prediction: 0.1941075325012207, label: 0.16475095785440613
# {'predictions': [{'score': 0.1466931402683258}]}
# idx: 127, nct_id: NCT01316926, prediction: 0.1466931402683258, label: 0.0
# {'predictions': [{'score': 0.5711166858673096}]}
# idx: 128, nct_id: NCT01071070, prediction: 0.5711166858673096, label: 0.027777777777777776
# {'predictions': [{'score': 0.6696575880050659}]}
# idx: 129, nct_id: NCT01738646, prediction: 0.6696575880050659, label: 0.8541666666666666
# {'predictions': [{'score': 1.191772699356079}]}
# idx: 130, nct_id: NCT00581919, prediction: 1.191772699356079, label: 0.84375
# {'predictions': [{'score': 0.879747748374939}]}
# idx: 131, nct_id: NCT01042509, prediction: 0.879747748374939, label: 1.3333333333333333
# {'predictions': [{'score': 0.8589233756065369}]}
# idx: 132, nct_id: NCT00672243, prediction: 0.8589233756065369, label: 0.5
# {'predictions': [{'score': -0.6865968108177185}]}
# idx: 133, nct_id: NCT00676130, prediction: -0.6865968108177185, label: 0.013071895424836602
# {'predictions': [{'score': 0.9139930605888367}]}
# idx: 134, nct_id: NCT00108069, prediction: 0.9139930605888367, label: 0.9302325581395349
# {'predictions': [{'score': 0.21574559807777405}]}
# idx: 135, nct_id: NCT01454505, prediction: 0.21574559807777405, label: 0.0
# {'predictions': [{'score': 0.4381248652935028}]}
# idx: 136, nct_id: NCT01355302, prediction: 0.4381248652935028, label: 2.2857142857142856
# {'predictions': [{'score': 0.20927277207374573}]}
# idx: 137, nct_id: NCT01558271, prediction: 0.20927277207374573, label: 0.09146341463414634
# {'predictions': [{'score': 0.05752405524253845}]}
# idx: 138, nct_id: NCT01334229, prediction: 0.05752405524253845, label: 0.0
# {'predictions': [{'score': 0.46100518107414246}]}
# idx: 139, nct_id: NCT01441076, prediction: 0.46100518107414246, label: 0.8333333333333334
# {'predictions': [{'score': 0.3864104747772217}]}
# idx: 140, nct_id: NCT01370369, prediction: 0.3864104747772217, label: 0.0
# {'predictions': [{'score': 1.5888397693634033}]}
# idx: 141, nct_id: NCT00948064, prediction: 1.5888397693634033, label: 2.1
# {'predictions': [{'score': 0.10441030561923981}]}
# idx: 142, nct_id: NCT01456130, prediction: 0.10441030561923981, label: 0.1791044776119403
# {'predictions': [{'score': 0.5099586248397827}]}
# idx: 143, nct_id: NCT00658775, prediction: 0.5099586248397827, label: 0.011225444340505144
# {'predictions': [{'score': -0.17074722051620483}]}
# idx: 144, nct_id: NCT00591227, prediction: -0.17074722051620483, label: 0.0
# {'predictions': [{'score': 0.8741000294685364}]}
# idx: 145, nct_id: NCT00096538, prediction: 0.8741000294685364, label: 0.6666666666666666
# {'predictions': [{'score': 0.2860186696052551}]}
# idx: 146, nct_id: NCT00633217, prediction: 0.2860186696052551, label: 0.0931174089068826
# {'predictions': [{'score': 1.545292615890503}]}
# idx: 147, nct_id: NCT00391586, prediction: 1.545292615890503, label: 0.24444444444444444
# {'predictions': [{'score': -0.03951108455657959}]}
# idx: 148, nct_id: NCT01083485, prediction: -0.03951108455657959, label: 0.029197080291970802
# {'predictions': [{'score': 0.026784539222717285}]}
# idx: 149, nct_id: NCT01018134, prediction: 0.026784539222717285, label: 0.0
# {'predictions': [{'score': 1.489104986190796}]}
# idx: 150, nct_id: NCT01014208, prediction: 1.489104986190796, label: 1.6845637583892616
# {'predictions': [{'score': -0.056262969970703125}]}
# idx: 151, nct_id: NCT01144949, prediction: -0.056262969970703125, label: 0.03347280334728033
# {'predictions': [{'score': 0.3706440031528473}]}
# idx: 152, nct_id: NCT00424476, prediction: 0.3706440031528473, label: 0.3942196531791908
# {'predictions': [{'score': 0.49734431505203247}]}
# idx: 153, nct_id: NCT00412737, prediction: 0.49734431505203247, label: 0.1949685534591195
# {'predictions': [{'score': -0.1309652328491211}]}
# idx: 154, nct_id: NCT00768053, prediction: -0.1309652328491211, label: 0.09259259259259259
# {'predictions': [{'score': 1.4617271423339844}]}
# idx: 155, nct_id: NCT01281865, prediction: 1.4617271423339844, label: 0.42857142857142855
# {'predictions': [{'score': 0.1849515289068222}]}
# idx: 156, nct_id: NCT00514904, prediction: 0.1849515289068222, label: 0.051827242524916946
# {'predictions': [{'score': 0.017680346965789795}]}
# idx: 157, nct_id: NCT01452152, prediction: 0.017680346965789795, label: 0.2222222222222222
# {'predictions': [{'score': 0.41786861419677734}]}
# idx: 158, nct_id: NCT00924170, prediction: 0.41786861419677734, label: 3.1666666666666665
# {'predictions': [{'score': 0.27551329135894775}]}
# idx: 159, nct_id: NCT00579826, prediction: 0.27551329135894775, label: 0.0
# {'predictions': [{'score': -0.12615430355072021}]}
# idx: 160, nct_id: NCT00396409, prediction: -0.12615430355072021, label: 0.1953125
# {'predictions': [{'score': 0.1987365335226059}]}
# idx: 161, nct_id: NCT01078116, prediction: 0.1987365335226059, label: 0.04838709677419355
# {'predictions': [{'score': 0.26556894183158875}]}
# idx: 162, nct_id: NCT00770653, prediction: 0.26556894183158875, label: 0.16393442622950818
# {'predictions': [{'score': 0.11289700865745544}]}
# idx: 163, nct_id: NCT01607450, prediction: 0.11289700865745544, label: 0.0
# {'predictions': [{'score': 0.1897759735584259}]}
# idx: 164, nct_id: NCT00987337, prediction: 0.1897759735584259, label: 0.19791666666666666
# {'predictions': [{'score': 0.5873388051986694}]}
# idx: 165, nct_id: NCT00142298, prediction: 0.5873388051986694, label: 0.17228464419475656
# {'predictions': [{'score': 0.7160150408744812}]}
# idx: 166, nct_id: NCT00592488, prediction: 0.7160150408744812, label: 0.0
# {'predictions': [{'score': 0.6356456279754639}]}
# idx: 167, nct_id: NCT00497770, prediction: 0.6356456279754639, label: 0.14285714285714285
# {'predictions': [{'score': 1.003096342086792}]}
# idx: 168, nct_id: NCT01087762, prediction: 1.003096342086792, label: 1.0461538461538462
# {'predictions': [{'score': 0.2290506809949875}]}
# idx: 169, nct_id: NCT01048125, prediction: 0.2290506809949875, label: 0.0
# {'predictions': [{'score': 1.2771694660186768}]}
# idx: 170, nct_id: NCT00619684, prediction: 1.2771694660186768, label: 1.2222222222222223
# {'predictions': [{'score': 0.2413477897644043}]}
# idx: 171, nct_id: NCT01346475, prediction: 0.2413477897644043, label: 0.0
# {'predictions': [{'score': 0.6101171970367432}]}
# idx: 172, nct_id: NCT00171834, prediction: 0.6101171970367432, label: 0.8314606741573034
# {'predictions': [{'score': 0.6188809275627136}]}
# idx: 173, nct_id: NCT01508117, prediction: 0.6188809275627136, label: 3.0
# {'predictions': [{'score': 0.23483224213123322}]}
# idx: 174, nct_id: NCT00934648, prediction: 0.23483224213123322, label: 0.0
# {'predictions': [{'score': 0.007516443729400635}]}
# idx: 175, nct_id: NCT02227368, prediction: 0.007516443729400635, label: 0.35
# {'predictions': [{'score': 0.9087731242179871}]}
# idx: 176, nct_id: NCT00479856, prediction: 0.9087731242179871, label: 0.3333333333333333
# {'predictions': [{'score': 0.03830207884311676}]}
# idx: 177, nct_id: NCT01532414, prediction: 0.03830207884311676, label: 0.0
# {'predictions': [{'score': 0.8829526305198669}]}
# idx: 178, nct_id: NCT00859937, prediction: 0.8829526305198669, label: 0.8
# {'predictions': [{'score': 0.10178469121456146}]}
# idx: 179, nct_id: NCT00166296, prediction: 0.10178469121456146, label: 0.0
# {'predictions': [{'score': 0.6378378868103027}]}
# idx: 180, nct_id: NCT00145249, prediction: 0.6378378868103027, label: 1.0769230769230769
# {'predictions': [{'score': 0.6188727021217346}]}
# idx: 181, nct_id: NCT00085644, prediction: 0.6188727021217346, label: 0.7365079365079366
# {'predictions': [{'score': -0.1978905200958252}]}
# idx: 182, nct_id: NCT02302716, prediction: -0.1978905200958252, label: 0.10344827586206896
# {'predictions': [{'score': 1.1472148895263672}]}
# idx: 183, nct_id: NCT00619242, prediction: 1.1472148895263672, label: 0.0
# {'predictions': [{'score': -0.46632176637649536}]}
# idx: 184, nct_id: NCT01830881, prediction: -0.46632176637649536, label: 0.0
# {'predictions': [{'score': 0.6990902423858643}]}
# idx: 185, nct_id: NCT00923910, prediction: 0.6990902423858643, label: 0.0
# {'predictions': [{'score': 0.20442050695419312}]}
# idx: 186, nct_id: NCT01898208, prediction: 0.20442050695419312, label: 0.0
# {'predictions': [{'score': -0.08126223087310791}]}
# idx: 187, nct_id: NCT02100579, prediction: -0.08126223087310791, label: 0.0
# {'predictions': [{'score': 0.17354446649551392}]}
# idx: 188, nct_id: NCT00683644, prediction: 0.17354446649551392, label: 0.0
# {'predictions': [{'score': 0.10740235447883606}]}
# idx: 189, nct_id: NCT01074008, prediction: 0.10740235447883606, label: 0.05405405405405406
# {'predictions': [{'score': -0.15867459774017334}]}
# idx: 190, nct_id: NCT00956085, prediction: -0.15867459774017334, label: 0.0
# {'predictions': [{'score': 0.03921614587306976}]}
# idx: 191, nct_id: NCT00614939, prediction: 0.03921614587306976, label: 0.21328671328671328
# {'predictions': [{'score': 0.08397237956523895}]}
# idx: 192, nct_id: NCT00870584, prediction: 0.08397237956523895, label: 0.0996309963099631
# {'predictions': [{'score': 0.7285493612289429}]}
# idx: 193, nct_id: NCT00796861, prediction: 0.7285493612289429, label: 0.75
# {'predictions': [{'score': 0.7547847032546997}]}
# idx: 194, nct_id: NCT00550173, prediction: 0.7547847032546997, label: 0.8259109311740891
# {'predictions': [{'score': 0.18099445104599}]}
# idx: 195, nct_id: NCT00699283, prediction: 0.18099445104599, label: 0.16129032258064516
# {'predictions': [{'score': 0.6549042463302612}]}
# idx: 196, nct_id: NCT00449163, prediction: 0.6549042463302612, label: 1.24
# {'predictions': [{'score': 0.9711485505104065}]}
# idx: 197, nct_id: NCT01313689, prediction: 0.9711485505104065, label: 2.0737704918032787
# {'predictions': [{'score': 0.6174038052558899}]}
# idx: 198, nct_id: NCT01369745, prediction: 0.6174038052558899, label: 0.08503401360544217
# {'predictions': [{'score': -0.1418936848640442}]}
# idx: 199, nct_id: NCT01072201, prediction: -0.1418936848640442, label: 0.0
# {'predictions': [{'score': -0.0695527195930481}]}
# idx: 200, nct_id: NCT01100255, prediction: -0.0695527195930481, label: 0.0
# {'predictions': [{'score': 0.23897245526313782}]}
# idx: 201, nct_id: NCT01072396, prediction: 0.23897245526313782, label: 0.05555555555555555
# {'predictions': [{'score': 0.3109224736690521}]}
# idx: 202, nct_id: NCT00435591, prediction: 0.3109224736690521, label: 0.32231404958677684
# {'predictions': [{'score': 0.05626840889453888}]}
# idx: 203, nct_id: NCT01680016, prediction: 0.05626840889453888, label: 0.003105590062111801
# {'predictions': [{'score': 0.38955429196357727}]}
# idx: 204, nct_id: NCT01489189, prediction: 0.38955429196357727, label: 1.3573770491803279
# {'predictions': [{'score': 0.7968543767929077}]}
# idx: 205, nct_id: NCT01088984, prediction: 0.7968543767929077, label: 2.5348837209302326
# {'predictions': [{'score': 0.44481492042541504}]}
# idx: 206, nct_id: NCT00287079, prediction: 0.44481492042541504, label: 0.05714285714285714
# {'predictions': [{'score': 0.9973695278167725}]}
# idx: 207, nct_id: NCT00081861, prediction: 0.9973695278167725, label: 1.8461538461538463
# {'predictions': [{'score': 0.056925803422927856}]}
# idx: 208, nct_id: NCT00106106, prediction: 0.056925803422927856, label: 0.03571428571428571
# {'predictions': [{'score': 0.238401859998703}]}
# idx: 209, nct_id: NCT01188564, prediction: 0.238401859998703, label: 0.02666666666666667
# {'predictions': [{'score': 0.050325408577919006}]}
# idx: 210, nct_id: NCT01411774, prediction: 0.050325408577919006, label: 0.0
# {'predictions': [{'score': 0.522557258605957}]}
# idx: 211, nct_id: NCT00788593, prediction: 0.522557258605957, label: 0.18292682926829268
# {'predictions': [{'score': 0.30909085273742676}]}
# idx: 212, nct_id: NCT00535782, prediction: 0.30909085273742676, label: 0.6439393939393939
# {'predictions': [{'score': 0.06693802773952484}]}
# idx: 213, nct_id: NCT00343915, prediction: 0.06693802773952484, label: 0.03745318352059925
# {'predictions': [{'score': 0.37124693393707275}]}
# idx: 214, nct_id: NCT00844714, prediction: 0.37124693393707275, label: 0.0
# {'predictions': [{'score': 0.16901680827140808}]}
# idx: 215, nct_id: NCT00760461, prediction: 0.16901680827140808, label: 0.0
# {'predictions': [{'score': 0.15923547744750977}]}
# idx: 216, nct_id: NCT00933608, prediction: 0.15923547744750977, label: 0.23529411764705882
# {'predictions': [{'score': 0.3878514766693115}]}
# idx: 217, nct_id: NCT00125593, prediction: 0.3878514766693115, label: 0.47827929646111467
# {'predictions': [{'score': 0.10768982768058777}]}
# idx: 218, nct_id: NCT00853229, prediction: 0.10768982768058777, label: 0.0
# {'predictions': [{'score': 0.6426599621772766}]}
# idx: 219, nct_id: NCT00137449, prediction: 0.6426599621772766, label: 1.4833333333333334
# {'predictions': [{'score': 0.06546521186828613}]}
# idx: 220, nct_id: NCT01946438, prediction: 0.06546521186828613, label: 0.019230769230769232
# {'predictions': [{'score': 0.19558605551719666}]}
# idx: 221, nct_id: NCT00486434, prediction: 0.19558605551719666, label: 0.34778911564625853
# {'predictions': [{'score': 0.30659013986587524}]}
# idx: 222, nct_id: NCT00696436, prediction: 0.30659013986587524, label: 0.024012393493415957
# {'predictions': [{'score': 0.016573771834373474}]}
# idx: 223, nct_id: NCT01011049, prediction: 0.016573771834373474, label: 0.0328
# {'predictions': [{'score': 0.051059454679489136}]}
# idx: 224, nct_id: NCT00197184, prediction: 0.051059454679489136, label: 0.0
# {'predictions': [{'score': 0.07110545039176941}]}
# idx: 225, nct_id: NCT00958243, prediction: 0.07110545039176941, label: 0.02536997885835095
# {'predictions': [{'score': 0.5777040719985962}]}
# idx: 226, nct_id: NCT01811732, prediction: 0.5777040719985962, label: 0.08484848484848485
# {'predictions': [{'score': 0.4194122850894928}]}
# idx: 227, nct_id: NCT00613314, prediction: 0.4194122850894928, label: 0.0006549646319098768
# {'predictions': [{'score': 0.41546791791915894}]}
# idx: 228, nct_id: NCT00467896, prediction: 0.41546791791915894, label: 1.435483870967742
# {'predictions': [{'score': -0.06302657723426819}]}
# idx: 229, nct_id: NCT01449929, prediction: -0.06302657723426819, label: 0.27459016393442626
# {'predictions': [{'score': 0.13826081156730652}]}
# idx: 230, nct_id: NCT01102270, prediction: 0.13826081156730652, label: 0.0
# {'predictions': [{'score': 0.23528601229190826}]}
# idx: 231, nct_id: NCT01017146, prediction: 0.23528601229190826, label: 0.008064516129032258
# {'predictions': [{'score': 0.051415786147117615}]}
# idx: 232, nct_id: NCT02071810, prediction: 0.051415786147117615, label: 0.058823529411764705
# {'predictions': [{'score': 0.3127753734588623}]}
# idx: 233, nct_id: NCT00757588, prediction: 0.3127753734588623, label: 0.2043956043956044
# {'predictions': [{'score': 0.4328298270702362}]}
# idx: 234, nct_id: NCT01182727, prediction: 0.4328298270702362, label: 0.0
# {'predictions': [{'score': -0.10769298672676086}]}
# idx: 235, nct_id: NCT01596842, prediction: -0.10769298672676086, label: 0.0
# {'predictions': [{'score': 0.17160022258758545}]}
# idx: 236, nct_id: NCT01002105, prediction: 0.17160022258758545, label: 0.0
# {'predictions': [{'score': 0.06731435656547546}]}
# idx: 237, nct_id: NCT00928187, prediction: 0.06731435656547546, label: 0.2555066079295154
# {'predictions': [{'score': 2.7120442390441895}]}
# idx: 238, nct_id: NCT00126581, prediction: 2.7120442390441895, label: 4.2712765957446805
# {'predictions': [{'score': -0.0019468069076538086}]}
# idx: 239, nct_id: NCT01210001, prediction: -0.0019468069076538086, label: 0.10420841683366733
# {'predictions': [{'score': 0.44358059763908386}]}
# idx: 240, nct_id: NCT00839540, prediction: 0.44358059763908386, label: 0.19047619047619047
# {'predictions': [{'score': 1.2501294612884521}]}
# idx: 241, nct_id: NCT00217581, prediction: 1.2501294612884521, label: 1.564102564102564
# {'predictions': [{'score': 0.7463564872741699}]}
# idx: 242, nct_id: NCT00075270, prediction: 0.7463564872741699, label: 0.7913793103448276
# {'predictions': [{'score': 0.2200416773557663}]}
# idx: 243, nct_id: NCT00349713, prediction: 0.2200416773557663, label: 0.0
# {'predictions': [{'score': 0.8050327897071838}]}
# idx: 244, nct_id: NCT01702961, prediction: 0.8050327897071838, label: 0.02666666666666667
# {'predictions': [{'score': 0.7435660362243652}]}
# idx: 245, nct_id: NCT01583374, prediction: 0.7435660362243652, label: 0.04693877551020408
# {'predictions': [{'score': -0.0702957808971405}]}
# idx: 246, nct_id: NCT01215955, prediction: -0.0702957808971405, label: 0.18800358102059087
# {'predictions': [{'score': 0.02764028310775757}]}
# idx: 247, nct_id: NCT01706952, prediction: 0.02764028310775757, label: 0.0
# {'predictions': [{'score': 0.8148254156112671}]}
# idx: 248, nct_id: NCT00793650, prediction: 0.8148254156112671, label: 0.3076923076923077
# {'predictions': [{'score': 0.6280757188796997}]}
# idx: 249, nct_id: NCT00683774, prediction: 0.6280757188796997, label: 0.0
# {'predictions': [{'score': -0.03863108158111572}]}
# idx: 250, nct_id: NCT01012414, prediction: -0.03863108158111572, label: 0.0
# {'predictions': [{'score': 0.7183558344841003}]}
# idx: 251, nct_id: NCT01469364, prediction: 0.7183558344841003, label: 0.06666666666666667
# {'predictions': [{'score': 0.11110557615756989}]}
# idx: 252, nct_id: NCT00464568, prediction: 0.11110557615756989, label: 0.0
# {'predictions': [{'score': 1.9773507118225098}]}
# idx: 253, nct_id: NCT01222195, prediction: 1.9773507118225098, label: 2.0
# {'predictions': [{'score': 0.7447693943977356}]}
# idx: 254, nct_id: NCT00606008, prediction: 0.7447693943977356, label: 2.066666666666667
# {'predictions': [{'score': 1.0406172275543213}]}
# idx: 255, nct_id: NCT01530997, prediction: 1.0406172275543213, label: 0.8666666666666667
# {'predictions': [{'score': 1.101730227470398}]}
# idx: 256, nct_id: NCT00238615, prediction: 1.101730227470398, label: 1.6923076923076923
# {'predictions': [{'score': -0.09241899847984314}]}
# idx: 257, nct_id: NCT00916357, prediction: -0.09241899847984314, label: 0.30434782608695654
# {'predictions': [{'score': 0.7462624907493591}]}
# idx: 258, nct_id: NCT00513435, prediction: 0.7462624907493591, label: 1.2222222222222223
# {'predictions': [{'score': 0.20537026226520538}]}
# idx: 259, nct_id: NCT02236546, prediction: 0.20537026226520538, label: 0.0
# {'predictions': [{'score': 1.1902987957000732}]}
# idx: 260, nct_id: NCT00107198, prediction: 1.1902987957000732, label: 0.0
# {'predictions': [{'score': 0.48613569140434265}]}
# idx: 261, nct_id: NCT00211809, prediction: 0.48613569140434265, label: 0.0
# {'predictions': [{'score': 0.32281196117401123}]}
# idx: 262, nct_id: NCT01257204, prediction: 0.32281196117401123, label: 0.10204081632653061
# {'predictions': [{'score': 0.24641099572181702}]}
# idx: 263, nct_id: NCT01949051, prediction: 0.24641099572181702, label: 0.0
# {'predictions': [{'score': 0.014978021383285522}]}
# idx: 264, nct_id: NCT01162733, prediction: 0.014978021383285522, label: 0.04040404040404041
# {'predictions': [{'score': 0.7697629928588867}]}
# idx: 265, nct_id: NCT02036424, prediction: 0.7697629928588867, label: 0.4444444444444444
# {'predictions': [{'score': 0.6824977397918701}]}
# idx: 266, nct_id: NCT00101400, prediction: 0.6824977397918701, label: 1.5185185185185186
# {'predictions': [{'score': 0.6590428352355957}]}
# idx: 267, nct_id: NCT00442416, prediction: 0.6590428352355957, label: 0.4125
# {'predictions': [{'score': 0.47043925523757935}]}
# idx: 268, nct_id: NCT00551642, prediction: 0.47043925523757935, label: 0.8325
# {'predictions': [{'score': 0.044431865215301514}]}
# idx: 269, nct_id: NCT01337297, prediction: 0.044431865215301514, label: 0.0
# {'predictions': [{'score': 0.7967870831489563}]}
# idx: 270, nct_id: NCT01085331, prediction: 0.7967870831489563, label: 1.5625
# {'predictions': [{'score': 0.10628631711006165}]}
# idx: 271, nct_id: NCT00826943, prediction: 0.10628631711006165, label: 0.0
# {'predictions': [{'score': 0.47470948100090027}]}
# idx: 272, nct_id: NCT00661427, prediction: 0.47470948100090027, label: 1.540983606557377
# {'predictions': [{'score': 0.1277557909488678}]}
# idx: 273, nct_id: NCT00959192, prediction: 0.1277557909488678, label: 0.0
# {'predictions': [{'score': 0.027279138565063477}]}
# idx: 274, nct_id: NCT01155999, prediction: 0.027279138565063477, label: 0.0
# {'predictions': [{'score': 0.5507966876029968}]}
# idx: 275, nct_id: NCT01280981, prediction: 0.5507966876029968, label: 0.041666666666666664
# {'predictions': [{'score': 0.6560589671134949}]}
# idx: 276, nct_id: NCT01459653, prediction: 0.6560589671134949, label: 0.0053475935828877
# {'predictions': [{'score': 0.812097430229187}]}
# idx: 277, nct_id: NCT00597038, prediction: 0.812097430229187, label: 0.94
# {'predictions': [{'score': 0.5038267970085144}]}
# idx: 278, nct_id: NCT00286468, prediction: 0.5038267970085144, label: 0.1
# {'predictions': [{'score': 0.8305698037147522}]}
# idx: 279, nct_id: NCT00102687, prediction: 0.8305698037147522, label: 1.7350993377483444
# {'predictions': [{'score': 0.13682089745998383}]}
# idx: 280, nct_id: NCT01026909, prediction: 0.13682089745998383, label: 0.0
# {'predictions': [{'score': 0.17725808918476105}]}
# idx: 281, nct_id: NCT00959894, prediction: 0.17725808918476105, label: 0.3125
# {'predictions': [{'score': 0.1910211443901062}]}
# idx: 282, nct_id: NCT00375752, prediction: 0.1910211443901062, label: 0.34523809523809523
# {'predictions': [{'score': -0.04563748836517334}]}
# idx: 283, nct_id: NCT00258908, prediction: -0.04563748836517334, label: 0.0
# {'predictions': [{'score': 0.25297480821609497}]}
# idx: 284, nct_id: NCT01082965, prediction: 0.25297480821609497, label: 0.0
# {'predictions': [{'score': 0.40814679861068726}]}
# idx: 285, nct_id: NCT01241513, prediction: 0.40814679861068726, label: 0.0
# {'predictions': [{'score': 0.30221712589263916}]}
# idx: 286, nct_id: NCT00261950, prediction: 0.30221712589263916, label: 1.6272727272727272
# {'predictions': [{'score': -0.022994965314865112}]}
# idx: 287, nct_id: NCT01707225, prediction: -0.022994965314865112, label: 0.0
# {'predictions': [{'score': 0.12985600531101227}]}
# idx: 288, nct_id: NCT01823536, prediction: 0.12985600531101227, label: 0.008602150537634409
# {'predictions': [{'score': 0.007803022861480713}]}
# idx: 289, nct_id: NCT00457197, prediction: 0.007803022861480713, label: 0.17777777777777778
# {'predictions': [{'score': 1.0969359874725342}]}
# idx: 290, nct_id: NCT01701674, prediction: 1.0969359874725342, label: 2.769230769230769
# {'predictions': [{'score': 0.6217396855354309}]}
# idx: 291, nct_id: NCT01838642, prediction: 0.6217396855354309, label: 1.3333333333333333
# {'predictions': [{'score': 0.6598244905471802}]}
# idx: 292, nct_id: NCT00884390, prediction: 0.6598244905471802, label: 0.2403846153846154
# {'predictions': [{'score': 0.12238575518131256}]}
# idx: 293, nct_id: NCT00071760, prediction: 0.12238575518131256, label: 0.84
# {'predictions': [{'score': -0.059846460819244385}]}
# idx: 294, nct_id: NCT00166166, prediction: -0.059846460819244385, label: 0.0
# {'predictions': [{'score': 0.09651309251785278}]}
# idx: 295, nct_id: NCT00687453, prediction: 0.09651309251785278, label: 0.0
# {'predictions': [{'score': 0.8271709084510803}]}
# idx: 296, nct_id: NCT00752791, prediction: 0.8271709084510803, label: 1.2372881355932204
# {'predictions': [{'score': 0.3891212046146393}]}
# idx: 297, nct_id: NCT00843635, prediction: 0.3891212046146393, label: 0.17142857142857143
# {'predictions': [{'score': -0.2584252953529358}]}
# idx: 298, nct_id: NCT02058628, prediction: -0.2584252953529358, label: 0.04954954954954955
# {'predictions': [{'score': 0.7223843336105347}]}
# idx: 299, nct_id: NCT02345772, prediction: 0.7223843336105347, label: 0.0
# {'predictions': [{'score': 0.2533308267593384}]}
# idx: 300, nct_id: NCT00705406, prediction: 0.2533308267593384, label: 0.0049382716049382715
# {'predictions': [{'score': 0.21946941316127777}]}
# idx: 301, nct_id: NCT00734500, prediction: 0.21946941316127777, label: 0.13333333333333333
# {'predictions': [{'score': 0.38715386390686035}]}
# idx: 302, nct_id: NCT01552343, prediction: 0.38715386390686035, label: 0.0
# {'predictions': [{'score': 0.8649317622184753}]}
# idx: 303, nct_id: NCT01075178, prediction: 0.8649317622184753, label: 0.8015717092337917
# {'predictions': [{'score': 0.4026748538017273}]}
# idx: 304, nct_id: NCT01659320, prediction: 0.4026748538017273, label: 0.0
# {'predictions': [{'score': 0.2246118038892746}]}
# idx: 305, nct_id: NCT00524264, prediction: 0.2246118038892746, label: 0.028225806451612902
# {'predictions': [{'score': 0.443886935710907}]}
# idx: 306, nct_id: NCT01631227, prediction: 0.443886935710907, label: 0.03308270676691729
# {'predictions': [{'score': 1.0002846717834473}]}
# idx: 307, nct_id: NCT01336634, prediction: 1.0002846717834473, label: 1.7183908045977012
# {'predictions': [{'score': 1.2276997566223145}]}
# idx: 308, nct_id: NCT01064622, prediction: 1.2276997566223145, label: 2.1610169491525424
# {'predictions': [{'score': 0.007943540811538696}]}
# idx: 309, nct_id: NCT01832766, prediction: 0.007943540811538696, label: 0.0
# {'predictions': [{'score': 0.012195289134979248}]}
# idx: 310, nct_id: NCT00641641, prediction: 0.012195289134979248, label: 0.0
# {'predictions': [{'score': 0.787841260433197}]}
# idx: 311, nct_id: NCT01045122, prediction: 0.787841260433197, label: 0.0
# {'predictions': [{'score': 0.9045161604881287}]}
# idx: 312, nct_id: NCT00126659, prediction: 0.9045161604881287, label: 0.2
# {'predictions': [{'score': 0.34627124667167664}]}
# idx: 313, nct_id: NCT01916941, prediction: 0.34627124667167664, label: 0.0
# {'predictions': [{'score': 1.508784532546997}]}
# idx: 314, nct_id: NCT00003875, prediction: 1.508784532546997, label: 0.3333333333333333
# {'predictions': [{'score': 0.35292673110961914}]}
# idx: 315, nct_id: NCT01215786, prediction: 0.35292673110961914, label: 0.0
# {'predictions': [{'score': 1.0148398876190186}]}
# idx: 316, nct_id: NCT01491633, prediction: 1.0148398876190186, label: 0.8
# {'predictions': [{'score': 0.45754274725914}]}
# idx: 317, nct_id: NCT01146288, prediction: 0.45754274725914, label: 0.15384615384615385
# {'predictions': [{'score': 0.017062902450561523}]}
# idx: 318, nct_id: NCT01045096, prediction: 0.017062902450561523, label: 0.05555555555555555
# {'predictions': [{'score': 0.34101587533950806}]}
# idx: 319, nct_id: NCT01204775, prediction: 0.34101587533950806, label: 0.07692307692307693
# {'predictions': [{'score': 0.1712099015712738}]}
# idx: 320, nct_id: NCT00531817, prediction: 0.1712099015712738, label: 0.45234248788368336
# {'predictions': [{'score': 0.005171984434127808}]}
# idx: 321, nct_id: NCT00200967, prediction: 0.005171984434127808, label: 0.11494252873563218
# {'predictions': [{'score': -0.20211493968963623}]}
# idx: 322, nct_id: NCT00584454, prediction: -0.20211493968963623, label: 0.4
# {'predictions': [{'score': 0.6357235908508301}]}
# idx: 323, nct_id: NCT01626092, prediction: 0.6357235908508301, label: 0.0
# {'predictions': [{'score': 0.1783328652381897}]}
# idx: 324, nct_id: NCT01455415, prediction: 0.1783328652381897, label: 0.08823529411764706
# {'predictions': [{'score': 0.623741090297699}]}
# idx: 325, nct_id: NCT00740714, prediction: 0.623741090297699, label: 0.12
# {'predictions': [{'score': 0.04088979959487915}]}
# idx: 326, nct_id: NCT00939874, prediction: 0.04088979959487915, label: 0.23076923076923078
# {'predictions': [{'score': 0.3471168577671051}]}
# idx: 327, nct_id: NCT01035333, prediction: 0.3471168577671051, label: 0.0
# {'predictions': [{'score': 0.5694229006767273}]}
# idx: 328, nct_id: NCT00630409, prediction: 0.5694229006767273, label: 0.0
# {'predictions': [{'score': 0.7567681074142456}]}
# idx: 329, nct_id: NCT00587132, prediction: 0.7567681074142456, label: 0.0
# {'predictions': [{'score': 0.6521890759468079}]}
# idx: 330, nct_id: NCT00612339, prediction: 0.6521890759468079, label: 0.6097560975609756
# {'predictions': [{'score': -0.013245999813079834}]}
# idx: 331, nct_id: NCT00610987, prediction: -0.013245999813079834, label: 0.449438202247191
# {'predictions': [{'score': 0.9523202776908875}]}
# idx: 332, nct_id: NCT00972959, prediction: 0.9523202776908875, label: 0.8235294117647058
# {'predictions': [{'score': 0.19876210391521454}]}
# idx: 333, nct_id: NCT02296931, prediction: 0.19876210391521454, label: 0.0
# {'predictions': [{'score': 0.040189921855926514}]}
# idx: 334, nct_id: NCT01450007, prediction: 0.040189921855926514, label: 0.06153846153846154
# {'predictions': [{'score': 0.24445198476314545}]}
# idx: 335, nct_id: NCT00790452, prediction: 0.24445198476314545, label: 0.0
# {'predictions': [{'score': 0.16477534174919128}]}
# idx: 336, nct_id: NCT00590161, prediction: 0.16477534174919128, label: 0.0
# {'predictions': [{'score': 0.05879366397857666}]}
# idx: 337, nct_id: NCT01529515, prediction: 0.05879366397857666, label: 0.2200392927308448
# {'predictions': [{'score': 0.3229176104068756}]}
# idx: 338, nct_id: NCT00586261, prediction: 0.3229176104068756, label: 0.05555555555555555
# {'predictions': [{'score': 0.4749770760536194}]}
# idx: 339, nct_id: NCT00182637, prediction: 0.4749770760536194, label: 0.0
# {'predictions': [{'score': 2.5997378826141357}]}
# idx: 340, nct_id: NCT00505635, prediction: 2.5997378826141357, label: 3.8
# {'predictions': [{'score': -0.41076213121414185}]}
# idx: 341, nct_id: NCT02120300, prediction: -0.41076213121414185, label: 0.11475409836065574
# {'predictions': [{'score': 2.2810282707214355}]}
# idx: 342, nct_id: NCT00045305, prediction: 2.2810282707214355, label: 9.176470588235293
# {'predictions': [{'score': 0.8829565048217773}]}
# idx: 343, nct_id: NCT00652314, prediction: 0.8829565048217773, label: 0.32989690721649484
# {'predictions': [{'score': 0.4294682443141937}]}
# idx: 344, nct_id: NCT01318967, prediction: 0.4294682443141937, label: 0.0
# {'predictions': [{'score': 0.18771874904632568}]}
# idx: 345, nct_id: NCT02091986, prediction: 0.18771874904632568, label: 0.0045351473922902496
# {'predictions': [{'score': 0.012909770011901855}]}
# idx: 346, nct_id: NCT01249833, prediction: 0.012909770011901855, label: 0.0
# {'predictions': [{'score': 0.46664488315582275}]}
# idx: 347, nct_id: NCT01324024, prediction: 0.46664488315582275, label: 0.0
# {'predictions': [{'score': -0.19112944602966309}]}
# idx: 348, nct_id: NCT01811706, prediction: -0.19112944602966309, label: 0.0
# {'predictions': [{'score': 0.004398763179779053}]}
# idx: 349, nct_id: NCT01114516, prediction: 0.004398763179779053, label: 0.0
# {'predictions': [{'score': 0.3468596935272217}]}
# idx: 350, nct_id: NCT01415531, prediction: 0.3468596935272217, label: 0.0265210608424337
# {'predictions': [{'score': 0.22676144540309906}]}
# idx: 351, nct_id: NCT00518882, prediction: 0.22676144540309906, label: 0.23554603854389722
# {'predictions': [{'score': 1.6294026374816895}]}
# idx: 352, nct_id: NCT00866918, prediction: 1.6294026374816895, label: 0.9537037037037037
# {'predictions': [{'score': 0.10158103704452515}]}
# idx: 353, nct_id: NCT01453036, prediction: 0.10158103704452515, label: 0.0
# {'predictions': [{'score': 0.22302353382110596}]}
# idx: 354, nct_id: NCT00543803, prediction: 0.22302353382110596, label: 0.16766467065868262
# {'predictions': [{'score': 0.2911684513092041}]}
# idx: 355, nct_id: NCT00844831, prediction: 0.2911684513092041, label: 0.08
# {'predictions': [{'score': 0.38636884093284607}]}
# idx: 356, nct_id: NCT00515099, prediction: 0.38636884093284607, label: 0.7068965517241379
# {'predictions': [{'score': 0.11017127335071564}]}
# idx: 357, nct_id: NCT01401465, prediction: 0.11017127335071564, label: 0.012232415902140673
# {'predictions': [{'score': 0.784382164478302}]}
# idx: 358, nct_id: NCT00670956, prediction: 0.784382164478302, label: 0.0
# {'predictions': [{'score': 0.10794205963611603}]}
# idx: 359, nct_id: NCT01387789, prediction: 0.10794205963611603, label: 0.38028169014084506
# ...
# {'predictions': [{'score': 0.23189622163772583}]}
# idx: 3660, nct_id: NCT00495521, prediction: 0.23189622163772583, label: 0.0
# {'predictions': [{'score': 1.6931970119476318}]}
# idx: 3661, nct_id: NCT01023308, prediction: 1.6931970119476318, label: 1.6848958333333333
# {'predictions': [{'score': 0.6987382173538208}]}
# idx: 3662, nct_id: NCT01740427, prediction: 0.6987382173538208, label: 0.4264264264264264
# {'predictions': [{'score': 0.2426062375307083}]}
# idx: 3663, nct_id: NCT02665221, prediction: 0.2426062375307083, label: 0.0
# {'predictions': [{'score': 0.1130874752998352}]}
# idx: 3664, nct_id: NCT01188694, prediction: 0.1130874752998352, label: 0.0
# {'predictions': [{'score': 0.6827464699745178}]}
# idx: 3665, nct_id: NCT01036802, prediction: 0.6827464699745178, label: 0.6666666666666666
# {'predictions': [{'score': 0.42850157618522644}]}
# idx: 3666, nct_id: NCT02004990, prediction: 0.42850157618522644, label: 0.0
# {'predictions': [{'score': 0.8334275484085083}]}
# idx: 3667, nct_id: NCT00319735, prediction: 0.8334275484085083, label: 1.1219512195121952
# {'predictions': [{'score': 0.5125675201416016}]}
# idx: 3668, nct_id: NCT01125813, prediction: 0.5125675201416016, label: 0.125
# {'predictions': [{'score': 0.11801734566688538}]}
# idx: 3669, nct_id: NCT00785577, prediction: 0.11801734566688538, label: 0.03663003663003663
# {'predictions': [{'score': 0.09017579257488251}]}
# idx: 3670, nct_id: NCT00668525, prediction: 0.09017579257488251, label: 0.03420752565564424
# {'predictions': [{'score': 0.14179369807243347}]}
# idx: 3671, nct_id: NCT01359449, prediction: 0.14179369807243347, label: 0.04878048780487805
# {'predictions': [{'score': 1.4575831890106201}]}
# idx: 3672, nct_id: NCT00853658, prediction: 1.4575831890106201, label: 2.3690543601359004
# {'predictions': [{'score': 0.5605623126029968}]}
# idx: 3673, nct_id: NCT00825565, prediction: 0.5605623126029968, label: 0.0
# {'predictions': [{'score': 0.29438528418540955}]}
# idx: 3674, nct_id: NCT01657461, prediction: 0.29438528418540955, label: 0.9540816326530612
# {'predictions': [{'score': 0.6039326190948486}]}
# idx: 3675, nct_id: NCT00206076, prediction: 0.6039326190948486, label: 0.42105263157894735
# {'predictions': [{'score': -0.24674761295318604}]}
# idx: 3676, nct_id: NCT00329732, prediction: -0.24674761295318604, label: 0.0
# {'predictions': [{'score': 0.6602652668952942}]}
# idx: 3677, nct_id: NCT01481116, prediction: 0.6602652668952942, label: 0.1466992665036675
# {'predictions': [{'score': 0.3168741762638092}]}
# idx: 3678, nct_id: NCT01018394, prediction: 0.3168741762638092, label: 0.0
# {'predictions': [{'score': 0.1108277291059494}]}
# idx: 3679, nct_id: NCT00217971, prediction: 0.1108277291059494, label: 0.05128205128205128
# {'predictions': [{'score': 0.4191279113292694}]}
# idx: 3680, nct_id: NCT00558272, prediction: 0.4191279113292694, label: 0.2446043165467626
# {'predictions': [{'score': 1.3019580841064453}]}
# idx: 3681, nct_id: NCT00323362, prediction: 1.3019580841064453, label: 1.9411764705882353
# {'predictions': [{'score': -0.23879516124725342}]}
# idx: 3682, nct_id: NCT00297037, prediction: -0.23879516124725342, label: 0.0
# {'predictions': [{'score': -0.23038923740386963}]}
# idx: 3683, nct_id: NCT01436162, prediction: -0.23038923740386963, label: 0.0036199095022624436
# {'predictions': [{'score': 0.47907567024230957}]}
# idx: 3684, nct_id: NCT01777412, prediction: 0.47907567024230957, label: 0.2
# {'predictions': [{'score': -0.12151902914047241}]}
# idx: 3685, nct_id: NCT00546000, prediction: -0.12151902914047241, label: 0.03571428571428571
# {'predictions': [{'score': 1.3897171020507812}]}
# idx: 3686, nct_id: NCT00451048, prediction: 1.3897171020507812, label: 1.3
# {'predictions': [{'score': -0.29410070180892944}]}
# idx: 3687, nct_id: NCT02300311, prediction: -0.29410070180892944, label: 0.0
# {'predictions': [{'score': 0.656551718711853}]}
# idx: 3688, nct_id: NCT00995488, prediction: 0.656551718711853, label: 3.0
# {'predictions': [{'score': 0.21646006405353546}]}
# idx: 3689, nct_id: NCT02492841, prediction: 0.21646006405353546, label: 0.0
# {'predictions': [{'score': -0.05466115474700928}]}
# idx: 3690, nct_id: NCT01453075, prediction: -0.05466115474700928, label: 0.0
# {'predictions': [{'score': 0.33409982919692993}]}
# idx: 3691, nct_id: NCT01463033, prediction: 0.33409982919692993, label: 0.2857142857142857
# {'predictions': [{'score': 0.1444879174232483}]}
# idx: 3692, nct_id: NCT01301079, prediction: 0.1444879174232483, label: 0.0
# {'predictions': [{'score': 0.13756036758422852}]}
# idx: 3693, nct_id: NCT01396057, prediction: 0.13756036758422852, label: 0.20081967213114754
# {'predictions': [{'score': -0.15618324279785156}]}
# idx: 3694, nct_id: NCT01077375, prediction: -0.15618324279785156, label: 0.037383177570093455
# {'predictions': [{'score': 0.6152163743972778}]}
# idx: 3695, nct_id: NCT00661453, prediction: 0.6152163743972778, label: 2.45
# {'predictions': [{'score': 0.1351536512374878}]}
# idx: 3696, nct_id: NCT00917644, prediction: 0.1351536512374878, label: 0.0
# {'predictions': [{'score': 0.3075610399246216}]}
# idx: 3697, nct_id: NCT01149876, prediction: 0.3075610399246216, label: 0.0
# {'predictions': [{'score': 0.2803395390510559}]}
# idx: 3698, nct_id: NCT00754546, prediction: 0.2803395390510559, label: 0.0
# {'predictions': [{'score': 0.3486848473548889}]}
# idx: 3699, nct_id: NCT00856609, prediction: 0.3486848473548889, label: 0.0
# {'predictions': [{'score': -0.11448565125465393}]}
# idx: 3700, nct_id: NCT00530790, prediction: -0.11448565125465393, label: 0.0
# {'predictions': [{'score': -0.10628265142440796}]}
# idx: 3701, nct_id: NCT01035944, prediction: -0.10628265142440796, label: 0.0
# {'predictions': [{'score': 1.1641480922698975}]}
# idx: 3702, nct_id: NCT01774851, prediction: 1.1641480922698975, label: 1.4880952380952381
# {'predictions': [{'score': 0.6724144220352173}]}
# idx: 3703, nct_id: NCT00389974, prediction: 0.6724144220352173, label: 1.6842105263157894
# {'predictions': [{'score': 0.425484299659729}]}
# idx: 3704, nct_id: NCT00611026, prediction: 0.425484299659729, label: 0.028547786512205214
# {'predictions': [{'score': 0.6324198246002197}]}
# idx: 3705, nct_id: NCT00831493, prediction: 0.6324198246002197, label: 0.0
# {'predictions': [{'score': 0.011822313070297241}]}
# idx: 3706, nct_id: NCT00927069, prediction: 0.011822313070297241, label: 0.0
# {'predictions': [{'score': 2.2326087951660156}]}
# idx: 3707, nct_id: NCT01442714, prediction: 2.2326087951660156, label: 4.181818181818182
# {'predictions': [{'score': 0.10972584784030914}]}
# idx: 3708, nct_id: NCT02340338, prediction: 0.10972584784030914, label: 0.0
# {'predictions': [{'score': 0.37920308113098145}]}
# idx: 3709, nct_id: NCT00608322, prediction: 0.37920308113098145, label: 0.6122448979591837
# {'predictions': [{'score': 0.0643049031496048}]}
# idx: 3710, nct_id: NCT01774968, prediction: 0.0643049031496048, label: 0.4338461538461538
# {'predictions': [{'score': -0.24429208040237427}]}
# idx: 3711, nct_id: NCT02097108, prediction: -0.24429208040237427, label: 0.18181818181818182
# {'predictions': [{'score': -0.06724551320075989}]}
# idx: 3712, nct_id: NCT01557166, prediction: -0.06724551320075989, label: 0.0947075208913649
# {'predictions': [{'score': -0.1754976511001587}]}
# idx: 3713, nct_id: NCT00790062, prediction: -0.1754976511001587, label: 0.0
# {'predictions': [{'score': 0.5239671468734741}]}
# idx: 3714, nct_id: NCT00340379, prediction: 0.5239671468734741, label: 0.027777777777777776
# {'predictions': [{'score': 0.3527172803878784}]}
# idx: 3715, nct_id: NCT00820534, prediction: 0.3527172803878784, label: 0.0
# {'predictions': [{'score': -0.014998048543930054}]}
# idx: 3716, nct_id: NCT00528957, prediction: -0.014998048543930054, label: 0.26804123711340205
# {'predictions': [{'score': 0.22201839089393616}]}
# idx: 3717, nct_id: NCT00960076, prediction: 0.22201839089393616, label: 0.02127659574468085
# {'predictions': [{'score': 1.563107967376709}]}
# idx: 3718, nct_id: NCT00985192, prediction: 1.563107967376709, label: 1.163265306122449
# {'predictions': [{'score': 0.07687464356422424}]}
# idx: 3719, nct_id: NCT01787916, prediction: 0.07687464356422424, label: 0.0
# {'predictions': [{'score': 0.5980319380760193}]}
# idx: 3720, nct_id: NCT00394251, prediction: 0.5980319380760193, label: 0.6598984771573604
# {'predictions': [{'score': 0.46622028946876526}]}
# idx: 3721, nct_id: NCT02059135, prediction: 0.46622028946876526, label: 1.7583333333333333
# {'predictions': [{'score': 0.03173959255218506}]}
# idx: 3722, nct_id: NCT00429403, prediction: 0.03173959255218506, label: 0.0
# {'predictions': [{'score': -0.05700179934501648}]}
# idx: 3723, nct_id: NCT02310581, prediction: -0.05700179934501648, label: 0.05
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-024410db6023> in <module>()
#       2
#       3 for idx, train_line in enumerate(train_features):
# ----> 4     prediction = logistic_predictor.predict(train_line[1:].reshape(1, -1))
#       5     print(prediction)
#       6     result.append((train_line[0], prediction['predictions'][0]['score'], float(train_labels[idx])))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data)
#      84             request_args['Accept'] = self.accept
#      85
# ---> 86         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#      87
#      88         response_body = response['Body']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     312                     "%s() only accepts keyword arguments." % py_operation_name)
#     313             # The "self" in this scope is referring to the BaseClient.
# --> 314             return self._make_api_call(operation_name, kwargs)
#     315
#     316         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     597         else:
#     598             http, parsed_response = self._endpoint.make_request(
# --> 599                 operation_model, request_dict)
#     600
#     601         self.meta.events.emit(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     141         logger.debug("Making request for %s (verify_ssl=%s) with params: %s",
#     142                      operation_model, self.verify, request_dict)
# --> 143         return self._send_request(request_dict, operation_model)
#     144
#     145     def create_request(self, params, operation_model=None):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     168         request = self.create_request(request_dict, operation_model)
#     169         success_response, exception = self._get_response(
# --> 170             request, operation_model, attempts)
#     171         while self._needs_retry(attempts, operation_model, request_dict,
#     172                                 success_response, exception):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, attempts)
#     211                 request, verify=self.verify,
#     212                 stream=operation_model.has_streaming_output,
# --> 213                 proxies=self.proxies, timeout=self.timeout)
#     214         except ConnectionError as e:
#     215             # For a connection error, if it looks like it's a DNS
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/vendored/requests/sessions.py in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/vendored/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/vendored/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
# --> 374                 httplib_response = conn.getresponse()
#     375         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     376             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/python3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def evaluate(linear_predictor, test_features, test_labels, model_name, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  Return binary classification metrics.
    """
    # split the test data set into 100 batches and evaluate using prediction endpoint
    prediction_batches = [linear_predictor.predict(batch)['predictions'] for batch in np.array_split(test_features, 100)]
    # parse raw predictions json to exctract predicted label
    test_preds = np.concatenate([np.array([x['predicted_label'] for x in batch]) for batch in prediction_batches])
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1 = 2 * precision * recall / (precision + recall)
    
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actuals'], colnames=['predictions']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('F1:', f1))
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 'Precision': precision, 'Recall': recall, 'Accuracy': accuracy, 
             'F1': f1, 'Model': model_name}

# %% [markdown]
# The predictor.predict method call takes one parameter, the input data for which you want the SageMaker Endpoint to provide inference. predict will serialize the input data, and send it in as request to the SageMaker Endpoint by an InvokeEndpoint SageMaker operation. InvokeEndpoint operation requests can be made by predictor.predict, by boto3 SageMaker.runtime client or by AWS CLI.
